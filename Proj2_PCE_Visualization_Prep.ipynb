# %%
# Import Dependencies
import pandas as pd
import numpy as np
import sqlalchemy
from sqlalchemy import create_engine, MetaData, inspect
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Numeric, Text, Float
from sqlalchemy.sql import text
from sqlalchemy.orm import Session
from sqlalchemy.ext.automap import automap_base
from flask import Flask, jsonify, render_template, request, redirect
import json
import pprint

# %%
# Create an engine for the database and connect
engine = create_engine("sqlite:///data.sqlite", echo=False)
engine.connect()

# %%
#Inspect table names
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['DPI', 'FPSR', 'PCE']

# %%
# Reflect Database into ORM classes
Base = automap_base()
Base.prepare(engine,reflect=True)
Base.classes.keys()
# Out:
# []

# %%
# Create a reference to each table
class DPI(Base):
    __tablename__ = "DPI"
    __table_args__ = {"extend_existing":True}
    field1 = Column(Text,primary_key=True)

class FPSR(Base):
    __tablename__ = "FPSR"
    __table_args__ = {"extend_existing":True}
    DATE = Column(Text,primary_key=True)

class PCE(Base):
    __tablename__ = "PCE"
    __table_args__ = {"extend_existing":True}
    GeoName = Column(Text,primary_key=True)
    Line = Column(Text,primary_key=True)

Base.prepare()
session = Session(engine)
app = Flask(__name__)

# %%
GeoName_List = [g.GeoName for g in session.query(PCE.GeoName).distinct()]
GeoName_List
# Out:
# ['United States',
#  'Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming',
#  'New England',
#  'Mideast',
#  'Great Lakes',
#  'Plains',
#  'Southeast',
#  'Southwest',
#  'Rocky Mountain',
#  'Far West']

# %%
Description_List = [d.Description for d in session.query(PCE.Description).distinct()]
Description_List
# Out:
# ['Personal consumption expenditures',
#  'Goods',
#  'Durable goods',
#  'Motor vehicles and parts',
#  'Furnishings and durable household equipment',
#  'Recreational goods and vehicles',
#  'Other durable goods',
#  'Nondurable goods',
#  'Food and beverages purchased for off-premises consumption',
#  'Clothing and footwear',
#  'Gasoline and other energy goods',
#  'Other nondurable goods',
#  'Services',
#  'Household consumption expenditures (for services)',
#  'Housing and utilities',
#  'Health care',
#  'Transportation services',
#  'Recreation services',
#  'Food services and accommodations',
#  'Financial services and insurance',
#  'Other services',
#  'Final consumption expenditures of nonprofit institutions serving households (NPISHs)',
#  'Gross output of nonprofit institutions',
#  'Less: Receipts from sales of goods and services by nonprofit institutions']

# %%
Component_Name = [c.ComponentName for c in session.query(PCE.ComponentName).distinct()]
Component_Name
# Out:
# ['Total personal consumption expenditures (PCE) by state (millions of dollars)']

# %%
sql = "select * from PCE"
df = pd.read_sql(sql, engine)
df.drop(['GeoFIPS', 'ComponentId', 'Line', 'IndustryClassification'], axis=1, inplace=True)
df.head(10)
# Out:
#          GeoName Region                                      ComponentName  \
# 0  United States         Total personal consumption expenditures (PCE) ...
# 1  United States         Total personal consumption expenditures (PCE) ...
# 2  United States         Total personal consumption expenditures (PCE) ...
# 3  United States         Total personal consumption expenditures (PCE) ...
# 4  United States         Total personal consumption expenditures (PCE) ...
# 5  United States         Total personal consumption expenditures (PCE) ...
# 6  United States         Total personal consumption expenditures (PCE) ...
# 7  United States         Total personal consumption expenditures (PCE) ...
# 8  United States         Total personal consumption expenditures (PCE) ...
# 9  United States         Total personal consumption expenditures (PCE) ...
#
#                                          Description     1997     1998  \
# 0                  Personal consumption expenditures  5557762  5899792
# 1                                              Goods  2003806  2105478
# 2                                      Durable goods   715530   779295
# 3                           Motor vehicles and parts   293083   320205
# 4        Furnishings and durable household equipment   160491   173579
# 5                    Recreational goods and vehicles   174632   191360
# 6                                Other durable goods    87324    94151
# 7                                   Nondurable goods  1288276  1326183
# 8  Food and beverages purchased for off-premises ...   474776   487437
# 9                              Clothing and footwear   247496   257805
#
#       1999     2000     2001     2002    ...        2007      2008     2009  \
# 0  6303893  6789177  7099701  7380019    ...     9745473  10008303  9840449
# 1  2283640  2449635  2521834  2594547    ...     3356541   3370357  3191925
# 2   855570   912571   941515   985367    ...     1184633   1102283  1023319
# 3   350730   363227   383289   401347    ...      400573    339630   317058
# 4   191185   208106   214940   225868    ...      283458    268714   244311
# 5   210922   230858   234934   244772    ...      335780    329331   303775
# 6   102733   110380   108352   113380    ...      164822    164608   158175
# 7  1428070  1537064  1580319  1609180    ...     2171908   2268074  2168606
# 8   515530   540579   564003   575052    ...      737331    772884   769958
# 9   271097   280832   277868   278836    ...      323692    319506   306498
#
#        2010      2011      2012      2013      2014      2015      2016
# 0  10196850  10682155  11044056  11355529  11858228  12327828  12816386
# 1   3357470   3589317   3732508   3828877   3965012   4028728   4117111
# 2   1070692   1125327   1191860   1241693   1296383   1367137   1411006
# 3    341955    363458    395763    416132    441874    472169    480792
# 4    250417    260672    271383    281557    294270    311516    325154
# 5    312735    320981    336605    348100    357404    372392    385474
# 6    165585    180216    188109    195904    202835    211060    219586
# 7   2286778   2463990   2540648   2587184   2668629   2661591   2706105
# 8    788899    829146    848789    857547    884403    898957    915074
# 9    320558    338946    354287    363625    375954    385461    393654
#
# [10 rows x 24 columns]

# %%
# Return each row as a dictionary and add it to a list
dict_list = []
for data in df.to_dict(orient='records'):
    dict_list.append(data)

dict_list
# Out:
# [{'1997': '5557762',
#   '1998': '5899792',
#   '1999': '6303893',
#   '2000': '6789177',
#   '2001': '7099701',
#   '2002': '7380019',
#   '2003': '7760899',
#   '2004': '8255300',
#   '2005': '8789586',
#   '2006': '9299424',
#   '2007': '9745473',
#   '2008': '10008303',
#   '2009': '9840449',
#   '2010': '10196850',
#   '2011': '10682155',
#   '2012': '11044056',
#   '2013': '11355529',
#   '2014': '11858228',
#   '2015': '12327828',
#   '2016': '12816386',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Personal consumption expenditures',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '2003806',
#   '1998': '2105478',
#   '1999': '2283640',
#   '2000': '2449635',
#   '2001': '2521834',
#   '2002': '2594547',
#   '2003': '2716926',
#   '2004': '2895537',
#   '2005': '3075755',
#   '2006': '3231229',
#   '2007': '3356541',
#   '2008': '3370357',
#   '2009': '3191925',
#   '2010': '3357470',
#   '2011': '3589317',
#   '2012': '3732508',
#   '2013': '3828877',
#   '2014': '3965012',
#   '2015': '4028728',
#   '2016': '4117111',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Goods',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '715530',
#   '1998': '779295',
#   '1999': '855570',
#   '2000': '912571',
#   '2001': '941515',
#   '2002': '985367',
#   '2003': '1017526',
#   '2004': '1079823',
#   '2005': '1127231',
#   '2006': '1156115',
#   '2007': '1184633',
#   '2008': '1102283',
#   '2009': '1023319',
#   '2010': '1070692',
#   '2011': '1125327',
#   '2012': '1191860',
#   '2013': '1241693',
#   '2014': '1296383',
#   '2015': '1367137',
#   '2016': '1411006',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Durable goods',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '293083',
#   '1998': '320205',
#   '1999': '350730',
#   '2000': '363227',
#   '2001': '383289',
#   '2002': '401347',
#   '2003': '401518',
#   '2004': '409312',
#   '2005': '409954',
#   '2006': '394950',
#   '2007': '400573',
#   '2008': '339630',
#   '2009': '317058',
#   '2010': '341955',
#   '2011': '363458',
#   '2012': '395763',
#   '2013': '416132',
#   '2014': '441874',
#   '2015': '472169',
#   '2016': '480792',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Motor vehicles and parts',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '160491',
#   '1998': '173579',
#   '1999': '191185',
#   '2000': '208106',
#   '2001': '214940',
#   '2002': '225868',
#   '2003': '235161',
#   '2004': '254311',
#   '2005': '271273',
#   '2006': '283597',
#   '2007': '283458',
#   '2008': '268714',
#   '2009': '244311',
#   '2010': '250417',
#   '2011': '260672',
#   '2012': '271383',
#   '2013': '281557',
#   '2014': '294270',
#   '2015': '311516',
#   '2016': '325154',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Furnishings and durable household equipment',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '174632',
#   '1998': '191360',
#   '1999': '210922',
#   '2000': '230858',
#   '2001': '234934',
#   '2002': '244772',
#   '2003': '259193',
#   '2004': '284088',
#   '2005': '305023',
#   '2006': '324101',
#   '2007': '335780',
#   '2008': '329331',
#   '2009': '303775',
#   '2010': '312735',
#   '2011': '320981',
#   '2012': '336605',
#   '2013': '348100',
#   '2014': '357404',
#   '2015': '372392',
#   '2016': '385474',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Recreational goods and vehicles',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '87324',
#   '1998': '94151',
#   '1999': '102733',
#   '2000': '110380',
#   '2001': '108352',
#   '2002': '113380',
#   '2003': '121654',
#   '2004': '132112',
#   '2005': '140981',
#   '2006': '153467',
#   '2007': '164822',
#   '2008': '164608',
#   '2009': '158175',
#   '2010': '165585',
#   '2011': '180216',
#   '2012': '188109',
#   '2013': '195904',
#   '2014': '202835',
#   '2015': '211060',
#   '2016': '219586',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Other durable goods',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '1288276',
#   '1998': '1326183',
#   '1999': '1428070',
#   '2000': '1537064',
#   '2001': '1580319',
#   '2002': '1609180',
#   '2003': '1699400',
#   '2004': '1815714',
#   '2005': '1948524',
#   '2006': '2075114',
#   '2007': '2171908',
#   '2008': '2268074',
#   '2009': '2168606',
#   '2010': '2286778',
#   '2011': '2463990',
#   '2012': '2540648',
#   '2013': '2587184',
#   '2014': '2668629',
#   '2015': '2661591',
#   '2016': '2706105',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Nondurable goods',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '474776',
#   '1998': '487437',
#   '1999': '515530',
#   '2000': '540579',
#   '2001': '564003',
#   '2002': '575052',
#   '2003': '599581',
#   '2004': '632604',
#   '2005': '668217',
#   '2006': '700260',
#   '2007': '737331',
#   '2008': '772884',
#   '2009': '769958',
#   '2010': '788899',
#   '2011': '829146',
#   '2012': '848789',
#   '2013': '857547',
#   '2014': '884403',
#   '2015': '898957',
#   '2016': '915074',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Food and beverages purchased for off-premises consumption',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '247496',
#   '1998': '257805',
#   '1999': '271097',
#   '2000': '280832',
#   '2001': '277868',
#   '2002': '278836',
#   '2003': '285347',
#   '2004': '297485',
#   '2005': '310659',
#   '2006': '320213',
#   '2007': '323692',
#   '2008': '319506',
#   '2009': '306498',
#   '2010': '320558',
#   '2011': '338946',
#   '2012': '354287',
#   '2013': '363625',
#   '2014': '375954',
#   '2015': '385461',
#   '2016': '393654',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Clothing and footwear',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '147662',
#   '1998': '132355',
#   '1999': '146545',
#   '2000': '184516',
#   '2001': '177985',
#   '2002': '167900',
#   '2003': '196412',
#   '2004': '232733',
#   '2005': '283770',
#   '2006': '319650',
#   '2007': '345546',
#   '2008': '389148',
#   '2009': '284500',
#   '2010': '333415',
#   '2011': '409558',
#   '2012': '416885',
#   '2013': '412161',
#   '2014': '397788',
#   '2015': '305138',
#   '2016': '273722',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Gasoline and other energy goods',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '418342',
#   '1998': '448586',
#   '1999': '494898',
#   '2000': '531137',
#   '2001': '560463',
#   '2002': '587392',
#   '2003': '618060',
#   '2004': '652892',
#   '2005': '685878',
#   '2006': '734991',
#   '2007': '765339',
#   '2008': '786536',
#   '2009': '807650',
#   '2010': '843906',
#   '2011': '886340',
#   '2012': '920687',
#   '2013': '953851',
#   '2014': '1010484',
#   '2015': '1072035',
#   '2016': '1123655',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Other nondurable goods',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '3553956',
#   '1998': '3794314',
#   '1999': '4020253',
#   '2000': '4339542',
#   '2001': '4577867',
#   '2002': '4785472',
#   '2003': '5043973',
#   '2004': '5359763',
#   '2005': '5713831',
#   '2006': '6068195',
#   '2007': '6388932',
#   '2008': '6637946',
#   '2009': '6648524',
#   '2010': '6839380',
#   '2011': '7092838',
#   '2012': '7311548',
#   '2013': '7526652',
#   '2014': '7893216',
#   '2015': '8299100',
#   '2016': '8699275',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Services',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '3448368',
#   '1998': '3670507',
#   '1999': '3882024',
#   '2000': '4181501',
#   '2001': '4398785',
#   '2002': '4587130',
#   '2003': '4838461',
#   '2004': '5153391',
#   '2005': '5503563',
#   '2006': '5829010',
#   '2007': '6140152',
#   '2008': '6355802',
#   '2009': '6372507',
#   '2010': '6564030',
#   '2011': '6817839',
#   '2012': '7018678',
#   '2013': '7221801',
#   '2014': '7579623',
#   '2015': '7969655',
#   '2016': '8340423',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Household consumption expenditures (for services)',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '1009822',
#   '1998': '1065472',
#   '1999': '1123133',
#   '2000': '1198556',
#   '2001': '1287492',
#   '2002': '1333584',
#   '2003': '1394121',
#   '2004': '1469083',
#   '2005': '1583621',
#   '2006': '1682374',
#   '2007': '1758184',
#   '2008': '1839073',
#   '2009': '1880993',
#   '2010': '1908992',
#   '2011': '1959856',
#   '2012': '1995376',
#   '2013': '2054235',
#   '2014': '2143466',
#   '2015': '2235414',
#   '2016': '2331526',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Housing and utilities',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '790949',
#   '1998': '832046',
#   '1999': '863590',
#   '2000': '918425',
#   '2001': '996564',
#   '2002': '1082873',
#   '2003': '1154646',
#   '2004': '1240115',
#   '2005': '1322285',
#   '2006': '1394226',
#   '2007': '1481787',
#   '2008': '1556486',
#   '2009': '1627380',
#   '2010': '1690701',
#   '2011': '1764711',
#   '2012': '1835856',
#   '2013': '1870905',
#   '2014': '1949934',
#   '2015': '2061247',
#   '2016': '2163744',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Health care',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '214308',
#   '1998': '227631',
#   '1999': '244091',
#   '2000': '263548',
#   '2001': '264704',
#   '2002': '258159',
#   '2003': '265464',
#   '2004': '276562',
#   '2005': '289385',
#   '2006': '302056',
#   '2007': '312216',
#   '2008': '311715',
#   '2009': '289694',
#   '2010': '292922',
#   '2011': '308124',
#   '2012': '319486',
#   '2013': '334511',
#   '2014': '357455',
#   '2015': '374249',
#   '2016': '392459',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Transportation services',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '208318',
#   '1998': '220205',
#   '1999': '238056',
#   '2000': '254392',
#   '2001': '262290',
#   '2002': '271404',
#   '2003': '289178',
#   '2004': '312103',
#   '2005': '328899',
#   '2006': '351945',
#   '2007': '375845',
#   '2008': '384491',
#   '2009': '375999',
#   '2010': '385051',
#   '2011': '400558',
#   '2012': '419776',
#   '2013': '434188',
#   '2014': '452503',
#   '2015': '470992',
#   '2016': '492637',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Recreation services',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '343428',
#   '1998': '361836',
#   '1999': '380330',
#   '2000': '408782',
#   '2001': '419663',
#   '2002': '436311',
#   '2003': '461897',
#   '2004': '496424',
#   '2005': '530642',
#   '2006': '566252',
#   '2007': '595634',
#   '2008': '612466',
#   '2009': '600334',
#   '2010': '617711',
#   '2011': '649504',
#   '2012': '685129',
#   '2013': '710827',
#   '2014': '754096',
#   '2015': '808152',
#   '2016': '849211',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Food services and accommodations',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '429244',
#   '1998': '467277',
#   '1999': '509124',
#   '2000': '566284',
#   '2001': '552822',
#   '2002': '562584',
#   '2003': '588472',
#   '2004': '635347',
#   '2005': '689633',
#   '2006': '724208',
#   '2007': '768491',
#   '2008': '771483',
#   '2009': '718956',
#   '2010': '763238',
#   '2011': '795799',
#   '2012': '789303',
#   '2013': '830742',
#   '2014': '888435',
#   '2015': '947202',
#   '2016': '984748',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Financial services and insurance',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '452299',
#   '1998': '496040',
#   '1999': '523700',
#   '2000': '571514',
#   '2001': '615250',
#   '2002': '642215',
#   '2003': '684683',
#   '2004': '723757',
#   '2005': '759098',
#   '2006': '807949',
#   '2007': '847995',
#   '2008': '880088',
#   '2009': '879151',
#   '2010': '905415',
#   '2011': '939287',
#   '2012': '973752',
#   '2013': '986393',
#   '2014': '1033734',
#   '2015': '1072399',
#   '2016': '1126098',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Other services',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '105588',
#   '1998': '123807',
#   '1999': '138229',
#   '2000': '158041',
#   '2001': '179082',
#   '2002': '198342',
#   '2003': '205512',
#   '2004': '206372',
#   '2005': '210268',
#   '2006': '239185',
#   '2007': '248780',
#   '2008': '282144',
#   '2009': '276017',
#   '2010': '275350',
#   '2011': '274999',
#   '2012': '292870',
#   '2013': '304851',
#   '2014': '313593',
#   '2015': '329445',
#   '2016': '358852',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Final consumption expenditures of nonprofit institutions serving households (NPISHs)',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '502624',
#   '1998': '542521',
#   '1999': '576319',
#   '2000': '621641',
#   '2001': '676441',
#   '2002': '737060',
#   '2003': '774643',
#   '2004': '818994',
#   '2005': '868456',
#   '2006': '932226',
#   '2007': '983141',
#   '2008': '1040912',
#   '2009': '1072564',
#   '2010': '1105893',
#   '2011': '1139563',
#   '2012': '1192997',
#   '2013': '1229654',
#   '2014': '1274635',
#   '2015': '1339190',
#   '2016': '1411338',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Gross output of nonprofit institutions',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '397036',
#   '1998': '418714',
#   '1999': '438090',
#   '2000': '463600',
#   '2001': '497359',
#   '2002': '538718',
#   '2003': '569131',
#   '2004': '612622',
#   '2005': '658188',
#   '2006': '693041',
#   '2007': '734361',
#   '2008': '758768',
#   '2009': '796547',
#   '2010': '830543',
#   '2011': '864564',
#   '2012': '900127',
#   '2013': '924803',
#   '2014': '961042',
#   '2015': '1009745',
#   '2016': '1052486',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Less: Receipts from sales of goods and services by nonprofit institutions',
#   'GeoName': 'United States',
#   'Region': ''},
#  {'1997': '75315',
#   '1998': '78854',
#   '1999': '83199',
#   '2000': '87604',
#   '2001': '90831',
#   '2002': '94911',
#   '2003': '99273',
#   '2004': '105474',
#   '2005': '113508',
#   '2006': '118927',
#   '2007': '123834',
#   '2008': '126943',
#   '2009': '125119',
#   '2010': '129660',
#   '2011': '134700',
#   '2012': '137570',
#   '2013': '140835',
#   '2014': '144674',
#   '2015': '148418',
#   '2016': '152397',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Personal consumption expenditures',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '30049',
#   '1998': '31111',
#   '1999': '33395',
#   '2000': '35008',
#   '2001': '36119',
#   '2002': '37812',
#   '2003': '39576',
#   '2004': '42190',
#   '2005': '45230',
#   '2006': '47249',
#   '2007': '49247',
#   '2008': '49425',
#   '2009': '47108',
#   '2010': '49285',
#   '2011': '52119',
#   '2012': '53643',
#   '2013': '54782',
#   '2014': '55760',
#   '2015': '56034',
#   '2016': '56573',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Goods',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '10211',
#   '1998': '10893',
#   '1999': '11757',
#   '2000': '12048',
#   '2001': '12313',
#   '2002': '13163',
#   '2003': '13599',
#   '2004': '14482',
#   '2005': '15242',
#   '2006': '15745',
#   '2007': '16613',
#   '2008': '15207',
#   '2009': '14226',
#   '2010': '14821',
#   '2011': '15439',
#   '2012': '16281',
#   '2013': '16839',
#   '2014': '17364',
#   '2015': '18176',
#   '2016': '18683',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Durable goods',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '4891',
#   '1998': '5285',
#   '1999': '5773',
#   '2000': '5814',
#   '2001': '6049',
#   '2002': '6431',
#   '2003': '6451',
#   '2004': '6591',
#   '2005': '6727',
#   '2006': '6672',
#   '2007': '6740',
#   '2008': '5616',
#   '2009': '5128',
#   '2010': '5636',
#   '2011': '5994',
#   '2012': '6439',
#   '2013': '6675',
#   '2014': '6949',
#   '2015': '7339',
#   '2016': '7489',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Motor vehicles and parts',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '2221',
#   '1998': '2335',
#   '1999': '2479',
#   '2000': '2588',
#   '2001': '2601',
#   '2002': '2777',
#   '2003': '2892',
#   '2004': '3138',
#   '2005': '3424',
#   '2006': '3622',
#   '2007': '3721',
#   '2008': '3494',
#   '2009': '3219',
#   '2010': '3243',
#   '2011': '3318',
#   '2012': '3429',
#   '2013': '3484',
#   '2014': '3595',
#   '2015': '3799',
#   '2016': '3982',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Furnishings and durable household equipment',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '1908',
#   '1998': '2007',
#   '1999': '2139',
#   '2000': '2216',
#   '2001': '2274',
#   '2002': '2458',
#   '2003': '2702',
#   '2004': '3040',
#   '2005': '3266',
#   '2006': '3446',
#   '2007': '3931',
#   '2008': '3869',
#   '2009': '3691',
#   '2010': '3694',
#   '2011': '3732',
#   '2012': '3948',
#   '2013': '4078',
#   '2014': '4126',
#   '2015': '4274',
#   '2016': '4400',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Recreational goods and vehicles',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '1190',
#   '1998': '1266',
#   '1999': '1367',
#   '2000': '1431',
#   '2001': '1389',
#   '2002': '1497',
#   '2003': '1554',
#   '2004': '1714',
#   '2005': '1825',
#   '2006': '2005',
#   '2007': '2222',
#   '2008': '2228',
#   '2009': '2188',
#   '2010': '2247',
#   '2011': '2395',
#   '2012': '2466',
#   '2013': '2602',
#   '2014': '2694',
#   '2015': '2764',
#   '2016': '2812',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Other durable goods',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '19839',
#   '1998': '20218',
#   '1999': '21638',
#   '2000': '22959',
#   '2001': '23805',
#   '2002': '24649',
#   '2003': '25977',
#   '2004': '27708',
#   '2005': '29988',
#   '2006': '31504',
#   '2007': '32634',
#   '2008': '34218',
#   '2009': '32882',
#   '2010': '34464',
#   '2011': '36680',
#   '2012': '37362',
#   '2013': '37943',
#   '2014': '38396',
#   '2015': '37858',
#   '2016': '37890',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Nondurable goods',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '7743',
#   '1998': '7854',
#   '1999': '8266',
#   '2000': '8320',
#   '2001': '8781',
#   '2002': '9037',
#   '2003': '9328',
#   '2004': '9671',
#   '2005': '10254',
#   '2006': '10259',
#   '2007': '10564',
#   '2008': '11066',
#   '2009': '11103',
#   '2010': '11277',
#   '2011': '11795',
#   '2012': '11858',
#   '2013': '11950',
#   '2014': '11979',
#   '2015': '12079',
#   '2016': '12306',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Food and beverages purchased for off-premises consumption',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '3550',
#   '1998': '3693',
#   '1999': '3745',
#   '2000': '3803',
#   '2001': '3794',
#   '2002': '3893',
#   '2003': '3820',
#   '2004': '3994',
#   '2005': '4210',
#   '2006': '4302',
#   '2007': '4332',
#   '2008': '4314',
#   '2009': '4201',
#   '2010': '4369',
#   '2011': '4540',
#   '2012': '4579',
#   '2013': '4671',
#   '2014': '4792',
#   '2015': '4942',
#   '2016': '5045',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Clothing and footwear',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '2437',
#   '1998': '2121',
#   '1999': '2341',
#   '2000': '3050',
#   '2001': '2853',
#   '2002': '2666',
#   '2003': '3148',
#   '2004': '3727',
#   '2005': '4556',
#   '2006': '5283',
#   '2007': '5632',
#   '2008': '6336',
#   '2009': '4613',
#   '2010': '5499',
#   '2011': '6737',
#   '2012': '6830',
#   '2013': '6763',
#   '2014': '6349',
#   '2015': '4806',
#   '2016': '4246',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Gasoline and other energy goods',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '6109',
#   '1998': '6550',
#   '1999': '7286',
#   '2000': '7787',
#   '2001': '8378',
#   '2002': '9051',
#   '2003': '9682',
#   '2004': '10317',
#   '2005': '10968',
#   '2006': '11659',
#   '2007': '12105',
#   '2008': '12502',
#   '2009': '12965',
#   '2010': '13318',
#   '2011': '13608',
#   '2012': '14095',
#   '2013': '14558',
#   '2014': '15276',
#   '2015': '16031',
#   '2016': '16292',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Other nondurable goods',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '45266',
#   '1998': '47743',
#   '1999': '49804',
#   '2000': '52597',
#   '2001': '54713',
#   '2002': '57099',
#   '2003': '59696',
#   '2004': '63284',
#   '2005': '68277',
#   '2006': '71678',
#   '2007': '74587',
#   '2008': '77517',
#   '2009': '78012',
#   '2010': '80376',
#   '2011': '82581',
#   '2012': '83927',
#   '2013': '86053',
#   '2014': '88915',
#   '2015': '92384',
#   '2016': '95824',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Services',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '44466',
#   '1998': '46728',
#   '1999': '48560',
#   '2000': '51220',
#   '2001': '53292',
#   '2002': '55635',
#   '2003': '58355',
#   '2004': '61825',
#   '2005': '66812',
#   '2006': '70227',
#   '2007': '72875',
#   '2008': '75416',
#   '2009': '76033',
#   '2010': '78491',
#   '2011': '80805',
#   '2012': '82145',
#   '2013': '84188',
#   '2014': '86889',
#   '2015': '90268',
#   '2016': '93363',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Household consumption expenditures (for services)',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '10895',
#   '1998': '11602',
#   '1999': '12126',
#   '2000': '12903',
#   '2001': '13651',
#   '2002': '14180',
#   '2003': '14785',
#   '2004': '15529',
#   '2005': '16836',
#   '2006': '18055',
#   '2007': '19072',
#   '2008': '20089',
#   '2009': '20843',
#   '2010': '21403',
#   '2011': '21965',
#   '2012': '22217',
#   '2013': '23011',
#   '2014': '23704',
#   '2015': '24203',
#   '2016': '25086',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Housing and utilities',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '12477',
#   '1998': '12880',
#   '1999': '13112',
#   '2000': '13712',
#   '2001': '14683',
#   '2002': '15855',
#   '2003': '16650',
#   '2004': '17566',
#   '2005': '19434',
#   '2006': '20230',
#   '2007': '20762',
#   '2008': '21521',
#   '2009': '22230',
#   '2010': '22921',
#   '2011': '23651',
#   '2012': '24446',
#   '2013': '24661',
#   '2014': '25354',
#   '2015': '26612',
#   '2016': '27386',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Health care',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '2128',
#   '1998': '2246',
#   '1999': '2352',
#   '2000': '2442',
#   '2001': '2427',
#   '2002': '2397',
#   '2003': '2446',
#   '2004': '2540',
#   '2005': '2701',
#   '2006': '2795',
#   '2007': '2836',
#   '2008': '2814',
#   '2009': '2605',
#   '2010': '2700',
#   '2011': '2814',
#   '2012': '2844',
#   '2013': '2903',
#   '2014': '2997',
#   '2015': '3091',
#   '2016': '3192',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Transportation services',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '3288',
#   '1998': '3276',
#   '1999': '3320',
#   '2000': '3356',
#   '2001': '3431',
#   '2002': '3528',
#   '2003': '3681',
#   '2004': '3931',
#   '2005': '4108',
#   '2006': '4268',
#   '2007': '4309',
#   '2008': '4402',
#   '2009': '4304',
#   '2010': '4341',
#   '2011': '4449',
#   '2012': '4503',
#   '2013': '4571',
#   '2014': '4662',
#   '2015': '4754',
#   '2016': '4912',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Recreation services',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '4194',
#   '1998': '4375',
#   '1999': '4641',
#   '2000': '4806',
#   '2001': '4911',
#   '2002': '5085',
#   '2003': '5448',
#   '2004': '5781',
#   '2005': '6233',
#   '2006': '6660',
#   '2007': '6985',
#   '2008': '7280',
#   '2009': '7311',
#   '2010': '7485',
#   '2011': '7747',
#   '2012': '8084',
#   '2013': '8316',
#   '2014': '8683',
#   '2015': '9245',
#   '2016': '9674',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Food services and accommodations',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '5813',
#   '1998': '6344',
#   '1999': '6844',
#   '2000': '7468',
#   '2001': '7256',
#   '2002': '7349',
#   '2003': '7710',
#   '2004': '8438',
#   '2005': '9183',
#   '2006': '9532',
#   '2007': '10100',
#   '2008': '10115',
#   '2009': '9519',
#   '2010': '10191',
#   '2011': '10401',
#   '2012': '10109',
#   '2013': '10643',
#   '2014': '11089',
#   '2015': '11700',
#   '2016': '12111',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Financial services and insurance',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '5671',
#   '1998': '6006',
#   '1999': '6164',
#   '2000': '6534',
#   '2001': '6932',
#   '2002': '7242',
#   '2003': '7636',
#   '2004': '8040',
#   '2005': '8316',
#   '2006': '8687',
#   '2007': '8811',
#   '2008': '9194',
#   '2009': '9220',
#   '2010': '9449',
#   '2011': '9779',
#   '2012': '9943',
#   '2013': '10082',
#   '2014': '10400',
#   '2015': '10662',
#   '2016': '11002',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Other services',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '800',
#   '1998': '1014',
#   '1999': '1244',
#   '2000': '1376',
#   '2001': '1421',
#   '2002': '1464',
#   '2003': '1341',
#   '2004': '1460',
#   '2005': '1466',
#   '2006': '1451',
#   '2007': '1712',
#   '2008': '2102',
#   '2009': '1979',
#   '2010': '1885',
#   '2011': '1776',
#   '2012': '1782',
#   '2013': '1865',
#   '2014': '2026',
#   '2015': '2116',
#   '2016': '2461',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Final consumption expenditures of nonprofit institutions serving households (NPISHs)',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '6320',
#   '1998': '6804',
#   '1999': '7353',
#   '2000': '7807',
#   '2001': '8183',
#   '2002': '8697',
#   '2003': '8861',
#   '2004': '9642',
#   '2005': '10347',
#   '2006': '10823',
#   '2007': '11839',
#   '2008': '12448',
#   '2009': '12748',
#   '2010': '13036',
#   '2011': '13280',
#   '2012': '13596',
#   '2013': '14055',
#   '2014': '14370',
#   '2015': '14972',
#   '2016': '15444',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Gross output of nonprofit institutions',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '5520',
#   '1998': '5790',
#   '1999': '6108',
#   '2000': '6430',
#   '2001': '6762',
#   '2002': '7233',
#   '2003': '7520',
#   '2004': '8183',
#   '2005': '8882',
#   '2006': '9372',
#   '2007': '10127',
#   '2008': '10347',
#   '2009': '10769',
#   '2010': '11151',
#   '2011': '11504',
#   '2012': '11814',
#   '2013': '12190',
#   '2014': '12345',
#   '2015': '12856',
#   '2016': '12983',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Less: Receipts from sales of goods and services by nonprofit institutions',
#   'GeoName': 'Alabama',
#   'Region': '5'},
#  {'1997': '14294',
#   '1998': '15030',
#   '1999': '15959',
#   '2000': '17251',
#   '2001': '18304',
#   '2002': '19687',
#   '2003': '20932',
#   '2004': '22464',
#   '2005': '24038',
#   '2006': '25423',
#   '2007': '26719',
#   '2008': '28190',
#   '2009': '28322',
#   '2010': '29663',
#   '2011': '31437',
#   '2012': '32474',
#   '2013': '33533',
#   '2014': '34819',
#   '2015': '35926',
#   '2016': '36758',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Personal consumption expenditures',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '5136',
#   '1998': '5292',
#   '1999': '5633',
#   '2000': '5854',
#   '2001': '6076',
#   '2002': '6508',
#   '2003': '6879',
#   '2004': '7414',
#   '2005': '7808',
#   '2006': '8121',
#   '2007': '8462',
#   '2008': '8840',
#   '2009': '8588',
#   '2010': '9057',
#   '2011': '9692',
#   '2012': '10001',
#   '2013': '10245',
#   '2014': '10465',
#   '2015': '10506',
#   '2016': '10563',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Goods',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '1679',
#   '1998': '1780',
#   '1999': '1898',
#   '2000': '1925',
#   '2001': '2032',
#   '2002': '2280',
#   '2003': '2398',
#   '2004': '2607',
#   '2005': '2707',
#   '2006': '2733',
#   '2007': '2806',
#   '2008': '2744',
#   '2009': '2648',
#   '2010': '2707',
#   '2011': '2789',
#   '2012': '2946',
#   '2013': '3006',
#   '2014': '3055',
#   '2015': '3130',
#   '2016': '3141',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Durable goods',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '574',
#   '1998': '627',
#   '1999': '709',
#   '2000': '742',
#   '2001': '793',
#   '2002': '900',
#   '2003': '920',
#   '2004': '938',
#   '2005': '895',
#   '2006': '833',
#   '2007': '830',
#   '2008': '714',
#   '2009': '701',
#   '2010': '715',
#   '2011': '727',
#   '2012': '797',
#   '2013': '818',
#   '2014': '827',
#   '2015': '858',
#   '2016': '822',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Motor vehicles and parts',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '361',
#   '1998': '376',
#   '1999': '391',
#   '2000': '400',
#   '2001': '429',
#   '2002': '494',
#   '2003': '521',
#   '2004': '561',
#   '2005': '618',
#   '2006': '635',
#   '2007': '643',
#   '2008': '675',
#   '2009': '658',
#   '2010': '672',
#   '2011': '693',
#   '2012': '721',
#   '2013': '732',
#   '2014': '752',
#   '2015': '768',
#   '2016': '757',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Furnishings and durable household equipment',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '524',
#   '1998': '547',
#   '1999': '550',
#   '2000': '532',
#   '2001': '565',
#   '2002': '631',
#   '2003': '684',
#   '2004': '812',
#   '2005': '880',
#   '2006': '923',
#   '2007': '967',
#   '2008': '988',
#   '2009': '940',
#   '2010': '943',
#   '2011': '961',
#   '2012': '1007',
#   '2013': '1019',
#   '2014': '1032',
#   '2015': '1040',
#   '2016': '1069',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Recreational goods and vehicles',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '220',
#   '1998': '229',
#   '1999': '248',
#   '2000': '251',
#   '2001': '244',
#   '2002': '256',
#   '2003': '274',
#   '2004': '296',
#   '2005': '314',
#   '2006': '342',
#   '2007': '365',
#   '2008': '368',
#   '2009': '348',
#   '2010': '377',
#   '2011': '408',
#   '2012': '421',
#   '2013': '437',
#   '2014': '444',
#   '2015': '464',
#   '2016': '493',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Other durable goods',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '3457',
#   '1998': '3512',
#   '1999': '3736',
#   '2000': '3930',
#   '2001': '4044',
#   '2002': '4227',
#   '2003': '4481',
#   '2004': '4807',
#   '2005': '5101',
#   '2006': '5388',
#   '2007': '5656',
#   '2008': '6095',
#   '2009': '5941',
#   '2010': '6350',
#   '2011': '6902',
#   '2012': '7055',
#   '2013': '7238',
#   '2014': '7410',
#   '2015': '7376',
#   '2016': '7422',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Nondurable goods',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '1463',
#   '1998': '1525',
#   '1999': '1575',
#   '2000': '1625',
#   '2001': '1704',
#   '2002': '1794',
#   '2003': '1912',
#   '2004': '2026',
#   '2005': '2155',
#   '2006': '2277',
#   '2007': '2418',
#   '2008': '2592',
#   '2009': '2595',
#   '2010': '2686',
#   '2011': '2842',
#   '2012': '2863',
#   '2013': '2886',
#   '2014': '2942',
#   '2015': '2969',
#   '2016': '3014',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Food and beverages purchased for off-premises consumption',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '513',
#   '1998': '517',
#   '1999': '526',
#   '2000': '536',
#   '2001': '540',
#   '2002': '549',
#   '2003': '568',
#   '2004': '591',
#   '2005': '606',
#   '2006': '622',
#   '2007': '625',
#   '2008': '636',
#   '2009': '613',
#   '2010': '633',
#   '2011': '669',
#   '2012': '687',
#   '2013': '693',
#   '2014': '711',
#   '2015': '728',
#   '2016': '742',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Clothing and footwear',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '467',
#   '1998': '404',
#   '1999': '446',
#   '2000': '565',
#   '2001': '513',
#   '2002': '487',
#   '2003': '533',
#   '2004': '625',
#   '2005': '700',
#   '2006': '751',
#   '2007': '810',
#   '2008': '943',
#   '2009': '716',
#   '2010': '850',
#   '2011': '1036',
#   '2012': '1069',
#   '2013': '1076',
#   '2014': '1060',
#   '2015': '798',
#   '2016': '698',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Gasoline and other energy goods',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '1014',
#   '1998': '1066',
#   '1999': '1188',
#   '2000': '1204',
#   '2001': '1287',
#   '2002': '1397',
#   '2003': '1468',
#   '2004': '1565',
#   '2005': '1639',
#   '2006': '1739',
#   '2007': '1803',
#   '2008': '1925',
#   '2009': '2016',
#   '2010': '2181',
#   '2011': '2356',
#   '2012': '2437',
#   '2013': '2583',
#   '2014': '2697',
#   '2015': '2881',
#   '2016': '2969',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Other nondurable goods',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '9158',
#   '1998': '9738',
#   '1999': '10326',
#   '2000': '11397',
#   '2001': '12228',
#   '2002': '13180',
#   '2003': '14053',
#   '2004': '15051',
#   '2005': '16230',
#   '2006': '17302',
#   '2007': '18257',
#   '2008': '19350',
#   '2009': '19734',
#   '2010': '20606',
#   '2011': '21745',
#   '2012': '22473',
#   '2013': '23289',
#   '2014': '24354',
#   '2015': '25421',
#   '2016': '26195',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Services',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '8727',
#   '1998': '9219',
#   '1999': '9772',
#   '2000': '10746',
#   '2001': '11520',
#   '2002': '12368',
#   '2003': '13234',
#   '2004': '14264',
#   '2005': '15321',
#   '2006': '16287',
#   '2007': '17181',
#   '2008': '18154',
#   '2009': '18454',
#   '2010': '19261',
#   '2011': '20304',
#   '2012': '20943',
#   '2013': '21699',
#   '2014': '22776',
#   '2015': '23790',
#   '2016': '24485',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Household consumption expenditures (for services)',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '2386',
#   '1998': '2529',
#   '1999': '2683',
#   '2000': '2830',
#   '2001': '3033',
#   '2002': '3184',
#   '2003': '3341',
#   '2004': '3546',
#   '2005': '3834',
#   '2006': '4148',
#   '2007': '4390',
#   '2008': '4619',
#   '2009': '4773',
#   '2010': '4929',
#   '2011': '5125',
#   '2012': '5245',
#   '2013': '5501',
#   '2014': '5755',
#   '2015': '5921',
#   '2016': '6090',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Housing and utilities',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '1715',
#   '1998': '1817',
#   '1999': '1988',
#   '2000': '2325',
#   '2001': '2688',
#   '2002': '3071',
#   '2003': '3335',
#   '2004': '3619',
#   '2005': '3923',
#   '2006': '4192',
#   '2007': '4447',
#   '2008': '4774',
#   '2009': '5144',
#   '2010': '5429',
#   '2011': '5868',
#   '2012': '6158',
#   '2013': '6362',
#   '2014': '6751',
#   '2015': '7262',
#   '2016': '7640',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Health care',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '458',
#   '1998': '489',
#   '1999': '527',
#   '2000': '590',
#   '2001': '624',
#   '2002': '614',
#   '2003': '632',
#   '2004': '652',
#   '2005': '681',
#   '2006': '697',
#   '2007': '721',
#   '2008': '739',
#   '2009': '691',
#   '2010': '694',
#   '2011': '716',
#   '2012': '730',
#   '2013': '778',
#   '2014': '813',
#   '2015': '836',
#   '2016': '878',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Transportation services',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '384',
#   '1998': '390',
#   '1999': '423',
#   '2000': '469',
#   '2001': '484',
#   '2002': '500',
#   '2003': '561',
#   '2004': '645',
#   '2005': '717',
#   '2006': '777',
#   '2007': '859',
#   '2008': '901',
#   '2009': '895',
#   '2010': '923',
#   '2011': '968',
#   '2012': '1022',
#   '2013': '1061',
#   '2014': '1141',
#   '2015': '1166',
#   '2016': '1169',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Recreation services',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '1089',
#   '1998': '1114',
#   '1999': '1174',
#   '2000': '1263',
#   '2001': '1297',
#   '2002': '1394',
#   '2003': '1512',
#   '2004': '1617',
#   '2005': '1702',
#   '2006': '1807',
#   '2007': '1884',
#   '2008': '1955',
#   '2009': '1910',
#   '2010': '1983',
#   '2011': '2115',
#   '2012': '2210',
#   '2013': '2313',
#   '2014': '2421',
#   '2015': '2572',
#   '2016': '2581',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Food services and accommodations',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '1062',
#   '1998': '1130',
#   '1999': '1215',
#   '2000': '1348',
#   '2001': '1320',
#   '2002': '1375',
#   '2003': '1454',
#   '2004': '1570',
#   '2005': '1728',
#   '2006': '1803',
#   '2007': '1956',
#   '2008': '2060',
#   '2009': '1962',
#   '2010': '2137',
#   '2011': '2259',
#   '2012': '2239',
#   '2013': '2307',
#   '2014': '2503',
#   '2015': '2561',
#   '2016': '2619',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Financial services and insurance',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '1633',
#   '1998': '1751',
#   '1999': '1763',
#   '2000': '1921',
#   '2001': '2073',
#   '2002': '2230',
#   '2003': '2400',
#   '2004': '2615',
#   '2005': '2736',
#   '2006': '2863',
#   '2007': '2924',
#   '2008': '3105',
#   '2009': '3079',
#   '2010': '3164',
#   '2011': '3253',
#   '2012': '3339',
#   '2013': '3377',
#   '2014': '3392',
#   '2015': '3472',
#   '2016': '3506',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Other services',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '431',
#   '1998': '519',
#   '1999': '554',
#   '2000': '651',
#   '2001': '708',
#   '2002': '811',
#   '2003': '819',
#   '2004': '787',
#   '2005': '909',
#   '2006': '1016',
#   '2007': '1076',
#   '2008': '1196',
#   '2009': '1280',
#   '2010': '1345',
#   '2011': '1441',
#   '2012': '1530',
#   '2013': '1590',
#   '2014': '1578',
#   '2015': '1631',
#   '2016': '1710',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Final consumption expenditures of nonprofit institutions serving households (NPISHs)',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '1396',
#   '1998': '1551',
#   '1999': '1616',
#   '2000': '1785',
#   '2001': '1890',
#   '2002': '2089',
#   '2003': '2113',
#   '2004': '2142',
#   '2005': '2423',
#   '2006': '2637',
#   '2007': '2794',
#   '2008': '2959',
#   '2009': '3139',
#   '2010': '3290',
#   '2011': '3480',
#   '2012': '3640',
#   '2013': '3768',
#   '2014': '3781',
#   '2015': '3946',
#   '2016': '4121',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Gross output of nonprofit institutions',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '965',
#   '1998': '1033',
#   '1999': '1062',
#   '2000': '1134',
#   '2001': '1181',
#   '2002': '1278',
#   '2003': '1295',
#   '2004': '1355',
#   '2005': '1514',
#   '2006': '1621',
#   '2007': '1718',
#   '2008': '1763',
#   '2009': '1860',
#   '2010': '1945',
#   '2011': '2039',
#   '2012': '2110',
#   '2013': '2178',
#   '2014': '2203',
#   '2015': '2315',
#   '2016': '2411',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Less: Receipts from sales of goods and services by nonprofit institutions',
#   'GeoName': 'Alaska',
#   'Region': '8'},
#  {'1997': '91060',
#   '1998': '97963',
#   '1999': '106158',
#   '2000': '115586',
#   '2001': '121250',
#   '2002': '127569',
#   '2003': '135905',
#   '2004': '148652',
#   '2005': '163859',
#   '2006': '179491',
#   '2007': '191312',
#   '2008': '193589',
#   '2009': '187937',
#   '2010': '193977',
#   '2011': '202286',
#   '2012': '208124',
#   '2013': '214601',
#   '2014': '223743',
#   '2015': '231267',
#   '2016': '239680',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Personal consumption expenditures',
#   'GeoName': 'Arizona',
#   'Region': '6'},
#  {'1997': '35126',
#   '1998': '37230',
#   '1999': '40881',
#   '2000': '44773',
#   '2001': '46514',
#   '2002': '48485',
#   '2003': '51928',
#   '2004': '57633',
#   '2005': '64445',
#   '2006': '70783',
#   '2007': '74248',
#   '2008': '72375',
#   '2009': '66788',
#   '2010': '69359',
#   '2011': '73906',
#   '2012': '76661',
#   '2013': '79166',
#   '2014': '82200',
#   '2015': '82993',
#   '2016': '84451',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Goods',
#   'GeoName': 'Arizona',
#   'Region': '6'},
#  {'1997': '12675',
#   '1998': '14075',
#   '1999': '15485',
#   '2000': '17163',
#   '2001': '17761',
#   '2002': '18712',
#   '2003': '19638',
#   '2004': '21723',
#   '2005': '23908',
#   '2006': '25826',
#   '2007': '25922',
#   '2008': '22552',
#   '2009': '19671',
#   '2010': '20337',
#   '2011': '21705',
#   '2012': '22919',
#   '2013': '23824',
#   '2014': '24887',
#   '2015': '26280',
#   '2016': '26991',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Durable goods',
#   'GeoName': 'Arizona',
#   'Region': '6'},
#  {'1997': '5311',
#   '1998': '5866',
#   '1999': '6464',
#   '2000': '6892',
#   '2001': '7374',
#   '2002': '7652',
#   '2003': '7888',
#   '2004': '8434',
#   '2005': '9065',
#   '2006': '9273',
#   '2007': '9418',
#   '2008': '7174',
#   '2009': '6071',
#   '2010': '6498',
#   '2011': '7096',
#   '2012': '7924',
#   '2013': '8474',
#   '2014': '9019',
#   '2015': '9713',
#   '2016': '9926',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Motor vehicles and parts',
#   'GeoName': 'Arizona',
#   'Region': '6'},
#  {'1997': '3056',
#   '1998': '3388',
#   '1999': '3636',
#   '2000': '4079',
#   '2001': '4207',
#   '2002': '4467',
#   '2003': '4707',
#   '2004': '5380',
#   '2005': '6174',
#   '2006': '6726',
#   '2007': '6393',
#   '2008': '5654',
#   '2009': '4826',
#   '2010': '4866',
#   '2011': '5334',
#   '2012': '5370',
#   '2013': '5456',
#   '2014': '5788',
#   '2015': '6064',
#   '2016': '6382',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Furnishings and durable household equipment',
#   'GeoName': 'Arizona',
#   'Region': '6'},
#  {'1997': '2927',
#   '1998': '3301',
#   '1999': '3698',
#   '2000': '4328',
#   '2001': '4316',
#   '2002': '4603',
#   '2003': '4871',
#   '2004': '5487',
#   '2005': '6005',
#   '2006': '6731',
#   '2007': '6759',
#   '2008': '6428',
#   '2009': '5637',
#   '2010': '5728',
#   '2011': '5838',
#   '2012': '6025',
#   '2013': '6190',
#   '2014': '6257',
#   '2015': '6564',
#   '2016': '6588',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Recreational goods and vehicles',
#   'GeoName': 'Arizona',
#   'Region': '6'},
#  {'1997': '1381',
#   '1998': '1521',
#   '1999': '1686',
#   '2000': '1864',
#   '2001': '1864',
#   '2002': '1989',
#   '2003': '2171',
#   '2004': '2422',
#   '2005': '2664',
#   '2006': '3096',
#   '2007': '3352',
#   '2008': '3297',
#   '2009': '3137',
#   '2010': '3244',
#   '2011': '3437',
#   '2012': '3601',
#   '2013': '3704',
#   '2014': '3823',
#   '2015': '3939',
#   '2016': '4094',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Other durable goods',
#   'GeoName': 'Arizona',
#   'Region': '6'},
#  {'1997': '22451',
#   '1998': '23155',
#   '1999': '25396',
#   '2000': '27610',
#   '2001': '28752',
#   '2002': '29773',
#   '2003': '32291',
#   '2004': '35910',
#   '2005': '40538',
#   '2006': '44956',
#   '2007': '48326',
#   '2008': '49823',
#   '2009': '47117',
#   '2010': '49023',
#   '2011': '52201',
#   '2012': '53742',
#   '2013': '55343',
#   '2014': '57313',
#   '2015': '56713',
#   '2016': '57461',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Nondurable goods',
#   'GeoName': 'Arizona',
#   'Region': '6'},
#  {'1997': '8130',
#   '1998': '8458',
#   '1999': '9158',
#   '2000': '9426',
#   '2001': '9922',
#   '2002': '10294',
#   '2003': '11021',
#   '2004': '12268',
#   '2005': '13570',
#   '2006': '14776',
#   '2007': '15801',
#   '2008': '16503',
#   '2009': '16061',
#   '2010': '16383',
#   '2011': '16846',
#   '2012': '16905',
#   '2013': '16951',
#   '2014': '17648',
#   '2015': '17868',
#   '2016': '17939',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Food and beverages purchased for off-premises consumption',
#   'GeoName': 'Arizona',
#   'Region': '6'},
#  {'1997': '3623',
#   '1998': '3748',
#   '1999': '4004',
#   '2000': '4301',
#   '2001': '4400',
#   '2002': '4594',
#   '2003': '4846',
#   '2004': '5223',
#   '2005': '5720',
#   '2006': '6161',
#   '2007': '6391',
#   '2008': '6251',
#   '2009': '6057',
#   '2010': '6315',
#   '2011': '6592',
#   '2012': '6826',
#   '2013': '7073',
#   '2014': '7320',
#   '2015': '7509',
#   '2016': '7640',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Clothing and footwear',
#   'GeoName': 'Arizona',
#   'Region': '6'},
#  {'1997': '2941',
#   '1998': '2647',
#   '1999': '2957',
#   '2000': '3713',
#   '2001': '3530',
#   '2002': '3211',
#   '2003': '3750',
#   '2004': '4386',
#   '2005': '5622',
#   '2006': '6474',
#   '2007': '7320',
#   '2008': '8007',
#   '2009': '5693',
#   '2010': '6395',
#   '2011': '7894',
#   '2012': '8239',
#   '2013': '8221',
#   '2014': '7947',
#   '2015': '6182',
#   '2016': '5525',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Gasoline and other energy goods',
#   'GeoName': 'Arizona',
#   'Region': '6'},
#  {'1997': '7757',
#   '1998': '8301',
#   '1999': '9277',
#   '2000': '10170',
#   '2001': '10900',
#   '2002': '11673',
#   '2003': '12674',
#   '2004': '14033',
#   '2005': '15626',
#   '2006': '17546',
#   '2007': '18814',
#   '2008': '19063',
#   '2009': '19306',
#   '2010': '19929',
#   '2011': '20869',
#   '2012': '21772',
#   '2013': '23098',
#   '2014': '24397',
#   '2015': '25153',
#   '2016': '26357',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Other nondurable goods',
#   'GeoName': 'Arizona',
#   'Region': '6'},
#  {'1997': '55934',
#   '1998': '60732',
#   '1999': '65276',
#   '2000': '70813',
#   '2001': '74736',
#   '2002': '79084',
#   '2003': '83976',
#   '2004': '91018',
#   '2005': '99414',
# ...
#   'Description': 'Other nondurable goods',
#   'GeoName': 'Rhode Island',
#   'Region': '1'},
#  {'1997': '14854',
#   '1998': '15783',
#   '1999': '16275',
#   '2000': '17584',
#   '2001': '18484',
#   '2002': '19446',
#   '2003': '20831',
#   '2004': '22257',
#   '2005': '23711',
#   '2006': '25039',
#   '2007': '26147',
#   '2008': '27103',
#   '2009': '26934',
#   '2010': '27537',
#   '2011': '28010',
#   '2012': '28409',
#   '2013': '29029',
#   '2014': '30352',
#   '2015': '31648',
#   '2016': '32714',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Services',
#   'GeoName': 'Rhode Island',
#   'Region': '1'},
#  {'1997': '14127',
#   '1998': '14910',
#   '1999': '15375',
#   '2000': '16579',
#   '2001': '17391',
#   '2002': '18242',
#   '2003': '19530',
#   '2004': '20939',
#   '2005': '22309',
#   '2006': '23517',
#   '2007': '24543',
#   '2008': '25401',
#   '2009': '25297',
#   '2010': '25951',
#   '2011': '26449',
#   '2012': '26816',
#   '2013': '27357',
#   '2014': '28680',
#   '2015': '29904',
#   '2016': '30872',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Household consumption expenditures (for services)',
#   'GeoName': 'Rhode Island',
#   'Region': '1'},
#  {'1997': '4126',
#   '1998': '4316',
#   '1999': '4541',
#   '2000': '4841',
#   '2001': '5210',
#   '2002': '5359',
#   '2003': '5646',
#   '2004': '6006',
#   '2005': '6535',
#   '2006': '6998',
#   '2007': '7242',
#   '2008': '7608',
#   '2009': '7607',
#   '2010': '7532',
#   '2011': '7517',
#   '2012': '7532',
#   '2013': '7592',
#   '2014': '7981',
#   '2015': '8273',
#   '2016': '8455',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Housing and utilities',
#   'GeoName': 'Rhode Island',
#   'Region': '1'},
#  {'1997': '3521',
#   '1998': '3761',
#   '1999': '3639',
#   '2000': '3845',
#   '2001': '4070',
#   '2002': '4443',
#   '2003': '4746',
#   '2004': '5137',
#   '2005': '5487',
#   '2006': '5756',
#   '2007': '6078',
#   '2008': '6370',
#   '2009': '6587',
#   '2010': '6883',
#   '2011': '7066',
#   '2012': '7180',
#   '2013': '7328',
#   '2014': '7612',
#   '2015': '7897',
#   '2016': '8003',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Health care',
#   'GeoName': 'Rhode Island',
#   'Region': '1'},
#  {'1997': '595',
#   '1998': '640',
#   '1999': '681',
#   '2000': '774',
#   '2001': '802',
#   '2002': '775',
#   '2003': '852',
#   '2004': '910',
#   '2005': '965',
#   '2006': '965',
#   '2007': '994',
#   '2008': '977',
#   '2009': '936',
#   '2010': '948',
#   '2011': '1000',
#   '2012': '1019',
#   '2013': '1056',
#   '2014': '1116',
#   '2015': '1168',
#   '2016': '1234',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Transportation services',
#   'GeoName': 'Rhode Island',
#   'Region': '1'},
#  {'1997': '702',
#   '1998': '719',
#   '1999': '750',
#   '2000': '832',
#   '2001': '869',
#   '2002': '906',
#   '2003': '995',
#   '2004': '1073',
#   '2005': '1168',
#   '2006': '1268',
#   '2007': '1351',
#   '2008': '1416',
#   '2009': '1405',
#   '2010': '1465',
#   '2011': '1495',
#   '2012': '1544',
#   '2013': '1589',
#   '2014': '1654',
#   '2015': '1689',
#   '2016': '1747',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Recreation services',
#   'GeoName': 'Rhode Island',
#   'Region': '1'},
#  {'1997': '1341',
#   '1998': '1372',
#   '1999': '1526',
#   '2000': '1688',
#   '2001': '1755',
#   '2002': '1878',
#   '2003': '2013',
#   '2004': '2130',
#   '2005': '2212',
#   '2006': '2281',
#   '2007': '2344',
#   '2008': '2371',
#   '2009': '2326',
#   '2010': '2413',
#   '2011': '2524',
#   '2012': '2654',
#   '2013': '2762',
#   '2014': '2927',
#   '2015': '3126',
#   '2016': '3303',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Food services and accommodations',
#   'GeoName': 'Rhode Island',
#   'Region': '1'},
#  {'1997': '1613',
#   '1998': '1752',
#   '1999': '1899',
#   '2000': '2094',
#   '2001': '2057',
#   '2002': '2144',
#   '2003': '2268',
#   '2004': '2413',
#   '2005': '2548',
#   '2006': '2636',
#   '2007': '2774',
#   '2008': '2749',
#   '2009': '2589',
#   '2010': '2775',
#   '2011': '2813',
#   '2012': '2776',
#   '2013': '2894',
#   '2014': '3066',
#   '2015': '3267',
#   '2016': '3378',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Financial services and insurance',
#   'GeoName': 'Rhode Island',
#   'Region': '1'},
#  {'1997': '2229',
#   '1998': '2349',
#   '1999': '2340',
#   '2000': '2504',
#   '2001': '2628',
#   '2002': '2737',
#   '2003': '3011',
#   '2004': '3270',
#   '2005': '3395',
#   '2006': '3613',
#   '2007': '3760',
#   '2008': '3910',
#   '2009': '3848',
#   '2010': '3935',
#   '2011': '4035',
#   '2012': '4111',
#   '2013': '4137',
#   '2014': '4325',
#   '2015': '4484',
#   '2016': '4753',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Other services',
#   'GeoName': 'Rhode Island',
#   'Region': '1'},
#  {'1997': '727',
#   '1998': '873',
#   '1999': '900',
#   '2000': '1005',
#   '2001': '1094',
#   '2002': '1204',
#   '2003': '1301',
#   '2004': '1318',
#   '2005': '1402',
#   '2006': '1522',
#   '2007': '1604',
#   '2008': '1701',
#   '2009': '1637',
#   '2010': '1586',
#   '2011': '1561',
#   '2012': '1592',
#   '2013': '1671',
#   '2014': '1671',
#   '2015': '1744',
#   '2016': '1841',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Final consumption expenditures of nonprofit institutions serving households (NPISHs)',
#   'GeoName': 'Rhode Island',
#   'Region': '1'},
#  {'1997': '2400',
#   '1998': '2623',
#   '1999': '2680',
#   '2000': '2861',
#   '2001': '3055',
#   '2002': '3328',
#   '2003': '3600',
#   '2004': '3776',
#   '2005': '3940',
#   '2006': '4193',
#   '2007': '4389',
#   '2008': '4563',
#   '2009': '4602',
#   '2010': '4659',
#   '2011': '4728',
#   '2012': '4836',
#   '2013': '5010',
#   '2014': '5057',
#   '2015': '5233',
#   '2016': '5332',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Gross output of nonprofit institutions',
#   'GeoName': 'Rhode Island',
#   'Region': '1'},
#  {'1997': '1673',
#   '1998': '1750',
#   '1999': '1780',
#   '2000': '1857',
#   '2001': '1961',
#   '2002': '2123',
#   '2003': '2299',
#   '2004': '2458',
#   '2005': '2538',
#   '2006': '2671',
#   '2007': '2785',
#   '2008': '2861',
#   '2009': '2966',
#   '2010': '3073',
#   '2011': '3167',
#   '2012': '3243',
#   '2013': '3339',
#   '2014': '3385',
#   '2015': '3489',
#   '2016': '3491',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Less: Receipts from sales of goods and services by nonprofit institutions',
#   'GeoName': 'Rhode Island',
#   'Region': '1'},
#  {'1997': '68757',
#   '1998': '73216',
#   '1999': '78554',
#   '2000': '83889',
#   '2001': '86942',
#   '2002': '90453',
#   '2003': '95572',
#   '2004': '102551',
#   '2005': '109853',
#   '2006': '117257',
#   '2007': '123977',
#   '2008': '128476',
#   '2009': '126575',
#   '2010': '133139',
#   '2011': '138294',
#   '2012': '142085',
#   '2013': '145830',
#   '2014': '152175',
#   '2015': '157909',
#   '2016': '165036',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Personal consumption expenditures',
#   'GeoName': 'South Carolina',
#   'Region': '5'},
#  {'1997': '27336',
#   '1998': '28848',
#   '1999': '31732',
#   '2000': '33669',
#   '2001': '33953',
#   '2002': '34844',
#   '2003': '36900',
#   '2004': '40096',
#   '2005': '43210',
#   '2006': '46139',
#   '2007': '48415',
#   '2008': '49328',
#   '2009': '46698',
#   '2010': '49683',
#   '2011': '52675',
#   '2012': '54359',
#   '2013': '55791',
#   '2014': '57548',
#   '2015': '57590',
#   '2016': '59125',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Goods',
#   'GeoName': 'South Carolina',
#   'Region': '5'},
#  {'1997': '9276',
#   '1998': '10126',
#   '1999': '11245',
#   '2000': '11817',
#   '2001': '11720',
#   '2002': '12119',
#   '2003': '12641',
#   '2004': '13560',
#   '2005': '14358',
#   '2006': '14973',
#   '2007': '15563',
#   '2008': '14243',
#   '2009': '12997',
#   '2010': '13826',
#   '2011': '14303',
#   '2012': '15147',
#   '2013': '16002',
#   '2014': '16750',
#   '2015': '17739',
#   '2016': '18516',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Durable goods',
#   'GeoName': 'South Carolina',
#   'Region': '5'},
#  {'1997': '4147',
#   '1998': '4538',
#   '1999': '5001',
#   '2000': '5204',
#   '2001': '5220',
#   '2002': '5524',
#   '2003': '5532',
#   '2004': '5517',
#   '2005': '5587',
#   '2006': '5547',
#   '2007': '5754',
#   '2008': '4777',
#   '2009': '4389',
#   '2010': '4895',
#   '2011': '5132',
#   '2012': '5609',
#   '2013': '5965',
#   '2014': '6255',
#   '2015': '6745',
#   '2016': '6925',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Motor vehicles and parts',
#   'GeoName': 'South Carolina',
#   'Region': '5'},
#  {'1997': '2199',
#   '1998': '2389',
#   '1999': '2662',
#   '2000': '2845',
#   '2001': '2747',
#   '2002': '2781',
#   '2003': '2940',
#   '2004': '3310',
#   '2005': '3575',
#   '2006': '3844',
#   '2007': '3868',
#   '2008': '3565',
#   '2009': '3138',
#   '2010': '3226',
#   '2011': '3301',
#   '2012': '3461',
#   '2013': '3670',
#   '2014': '3878',
#   '2015': '4097',
#   '2016': '4317',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Furnishings and durable household equipment',
#   'GeoName': 'South Carolina',
#   'Region': '5'},
#  {'1997': '1898',
#   '1998': '2099',
#   '1999': '2362',
#   '2000': '2453',
#   '2001': '2483',
#   '2002': '2461',
#   '2003': '2661',
#   '2004': '3034',
#   '2005': '3450',
#   '2006': '3645',
#   '2007': '3817',
#   '2008': '3778',
#   '2009': '3432',
#   '2010': '3596',
#   '2011': '3613',
#   '2012': '3784',
#   '2013': '3962',
#   '2014': '4111',
#   '2015': '4289',
#   '2016': '4545',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Recreational goods and vehicles',
#   'GeoName': 'South Carolina',
#   'Region': '5'},
#  {'1997': '1031',
#   '1998': '1101',
#   '1999': '1220',
#   '2000': '1314',
#   '2001': '1270',
#   '2002': '1353',
#   '2003': '1507',
#   '2004': '1698',
#   '2005': '1746',
#   '2006': '1936',
#   '2007': '2123',
#   '2008': '2123',
#   '2009': '2038',
#   '2010': '2109',
#   '2011': '2257',
#   '2012': '2294',
#   '2013': '2405',
#   '2014': '2507',
#   '2015': '2607',
#   '2016': '2730',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Other durable goods',
#   'GeoName': 'South Carolina',
#   'Region': '5'},
#  {'1997': '18060',
#   '1998': '18722',
#   '1999': '20487',
#   '2000': '21852',
#   '2001': '22234',
#   '2002': '22725',
#   '2003': '24259',
#   '2004': '26537',
#   '2005': '28852',
#   '2006': '31166',
#   '2007': '32852',
#   '2008': '35084',
#   '2009': '33702',
#   '2010': '35856',
#   '2011': '38372',
#   '2012': '39212',
#   '2013': '39788',
#   '2014': '40798',
#   '2015': '39851',
#   '2016': '40609',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Nondurable goods',
#   'GeoName': 'South Carolina',
#   'Region': '5'},
#  {'1997': '6773',
#   '1998': '7079',
#   '1999': '7584',
#   '2000': '7877',
#   '2001': '8067',
#   '2002': '8047',
#   '2003': '8213',
#   '2004': '8890',
#   '2005': '9710',
#   '2006': '10086',
#   '2007': '10652',
#   '2008': '11557',
#   '2009': '11751',
#   '2010': '12181',
#   '2011': '12426',
#   '2012': '12607',
#   '2013': '12775',
#   '2014': '13314',
#   '2015': '13369',
#   '2016': '13716',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Food and beverages purchased for off-premises consumption',
#   'GeoName': 'South Carolina',
#   'Region': '5'},
#  {'1997': '3562',
#   '1998': '3687',
#   '1999': '3940',
#   '2000': '3906',
#   '2001': '3870',
#   '2002': '3998',
#   '2003': '4238',
#   '2004': '4494',
#   '2005': '4315',
#   '2006': '4569',
#   '2007': '4697',
#   '2008': '4684',
#   '2009': '4523',
#   '2010': '4625',
#   '2011': '4804',
#   '2012': '4946',
#   '2013': '5069',
#   '2014': '5262',
#   '2015': '5414',
#   '2016': '5619',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Clothing and footwear',
#   'GeoName': 'South Carolina',
#   'Region': '5'},
#  {'1997': '2440',
#   '1998': '2203',
#   '1999': '2451',
#   '2000': '3172',
#   '2001': '2981',
#   '2002': '2909',
#   '2003': '3488',
#   '2004': '4167',
#   '2005': '5176',
#   '2006': '6035',
#   '2007': '6381',
#   '2008': '7253',
#   '2009': '5334',
#   '2010': '6385',
#   '2011': '7926',
#   '2012': '8116',
#   '2013': '7995',
#   '2014': '7589',
#   '2015': '5705',
#   '2016': '5154',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Gasoline and other energy goods',
#   'GeoName': 'South Carolina',
#   'Region': '5'},
#  {'1997': '5286',
#   '1998': '5752',
#   '1999': '6512',
#   '2000': '6897',
#   '2001': '7315',
#   '2002': '7772',
#   '2003': '8320',
#   '2004': '8985',
#   '2005': '9651',
#   '2006': '10476',
#   '2007': '11123',
#   '2008': '11590',
#   '2009': '12093',
#   '2010': '12666',
#   '2011': '13217',
#   '2012': '13543',
#   '2013': '13950',
#   '2014': '14632',
#   '2015': '15364',
#   '2016': '16119',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Other nondurable goods',
#   'GeoName': 'South Carolina',
#   'Region': '5'},
#  {'1997': '41421',
#   '1998': '44367',
#   '1999': '46821',
#   '2000': '50220',
#   '2001': '52989',
#   '2002': '55609',
#   '2003': '58672',
#   '2004': '62455',
#   '2005': '66642',
#   '2006': '71118',
#   '2007': '75561',
#   '2008': '79149',
#   '2009': '79877',
#   '2010': '83457',
#   '2011': '85619',
#   '2012': '87726',
#   '2013': '90039',
#   '2014': '94627',
#   '2015': '100319',
#   '2016': '105911',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Services',
#   'GeoName': 'South Carolina',
#   'Region': '5'},
#  {'1997': '40601',
#   '1998': '43308',
#   '1999': '45796',
#   '2000': '49027',
#   '2001': '51379',
#   '2002': '53745',
#   '2003': '56874',
#   '2004': '60806',
#   '2005': '65086',
#   '2006': '69205',
#   '2007': '73504',
#   '2008': '76780',
#   '2009': '77759',
#   '2010': '81555',
#   '2011': '83760',
#   '2012': '85656',
#   '2013': '87669',
#   '2014': '92099',
#   '2015': '97693',
#   '2016': '102944',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Household consumption expenditures (for services)',
#   'GeoName': 'South Carolina',
#   'Region': '5'},
#  {'1997': '10866',
#   '1998': '11546',
#   '1999': '12165',
#   '2000': '12985',
#   '2001': '13799',
#   '2002': '14330',
#   '2003': '15045',
#   '2004': '15957',
#   '2005': '17307',
#   '2006': '18340',
#   '2007': '19327',
#   '2008': '20273',
#   '2009': '20993',
#   '2010': '21805',
#   '2011': '22389',
#   '2012': '23073',
#   '2013': '23781',
#   '2014': '25115',
#   '2015': '26050',
#   '2016': '27493',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Housing and utilities',
#   'GeoName': 'South Carolina',
#   'Region': '5'},
#  {'1997': '9777',
#   '1998': '10309',
#   '1999': '10883',
#   '2000': '11703',
#   '2001': '12866',
#   '2002': '13971',
#   '2003': '14839',
#   '2004': '15907',
#   '2005': '16981',
#   '2006': '18060',
#   '2007': '19330',
#   '2008': '20616',
#   '2009': '21759',
#   '2010': '23412',
#   '2011': '23755',
#   '2012': '24049',
#   '2013': '24041',
#   '2014': '25068',
#   '2015': '26725',
#   '2016': '27947',
#   'ComponentName': 'Total personal consumption expenditures (PCE) by state (millions of dollars)',
#   'Description': 'Health care',
#   'GeoName': 'South Carolina',
#   'Region': '5'},
#  ...]
